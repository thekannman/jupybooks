# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
nx.draw_kamada_kawai(nx.balanced_tree(2,2))
plt.title("nx.balanced_tree(2,2)")
plt.show()
nx.draw_kamada_kawai(nx.balanced_tree(3,2))
plt.title("nx.balanced_tree(3,2)")
plt.show()
nx.draw_kamada_kawai(nx.balanced_tree(2,3))
plt.title("nx.balanced_tree(2,3)")
plt.show()

# %%
nx.draw_kamada_kawai(nx.barbell_graph(3,2))
plt.title("nx.barbell_graph(3,2)")
plt.show()
nx.draw_kamada_kawai(nx.barbell_graph(4,2))
plt.title("nx.barbell_graph(4,2)")
plt.show()
nx.draw_kamada_kawai(nx.barbell_graph(4,4))
plt.title("nx.barbell_graph(4,4)")
plt.show()

# %%
nx.draw_kamada_kawai(nx.complete_graph(3))
plt.title("nx.complete_graph(3)")
plt.show()
nx.draw_kamada_kawai(nx.complete_graph(5))
plt.title("nx.complete_graph(5)")
plt.show()
nx.draw_kamada_kawai(nx.complete_graph(10))
plt.title("nx.complete_graph(10)")
plt.show()

# %%
nx.draw_kamada_kawai(nx.complete_multipartite_graph(2,2))
plt.title("nx.complete_multipartite_graph(2,2)")
plt.show()
nx.draw_kamada_kawai(nx.complete_multipartite_graph(2,3))
plt.title("nx.complete_multipartite_graph(2,3)")
plt.show()
nx.draw_kamada_kawai(nx.complete_multipartite_graph(3,3))
plt.title("nx.complete_multipartite_graph(3,3)")
plt.show()
nx.draw_kamada_kawai(nx.complete_multipartite_graph(3,3,3))
plt.title("nx.complete_multipartite_graph(3,3,3)")
plt.show()

# %%
nx.draw_kamada_kawai(nx.circular_ladder_graph(2))
plt.title("nx.circular_ladder_graph(2)")
plt.show()
nx.draw_kamada_kawai(nx.circular_ladder_graph(3))
plt.title("nx.circular_ladder_graph(3)")
plt.show()
nx.draw_kamada_kawai(nx.circular_ladder_graph(4))
plt.title("nx.circular_ladder_graph(4)")
plt.show()

# %%
nx.draw_kamada_kawai(nx.cycle_graph(3))
plt.title("nx.circular_ladder_graph(3)")
plt.show()
nx.draw_kamada_kawai(nx.cycle_graph(6))
plt.title("nx.circular_ladder_graph(6)")
plt.show()

# %%
nx.draw_kamada_kawai(nx.dorogovtsev_goltsev_mendes_graph(1))
plt.title("nx.dorogovtsev_goltsev_mendes_graph(1)")
plt.show()
nx.draw_kamada_kawai(nx.dorogovtsev_goltsev_mendes_graph(2))
plt.title("nx.dorogovtsev_goltsev_mendes_graph(2)")
plt.show()
nx.draw_kamada_kawai(nx.dorogovtsev_goltsev_mendes_graph(4))
plt.title("nx.dorogovtsev_goltsev_mendes_graph(4)")
plt.show()

# %%
nx.draw_kamada_kawai(nx.ladder_graph(2))
plt.title("nx.ladder_graph(2)")
plt.show()
nx.draw_kamada_kawai(nx.ladder_graph(3))
plt.title("nx.ladder_graph(3)")
plt.show()
nx.draw_kamada_kawai(nx.ladder_graph(8))
plt.title("nx.ladder_graph(8)")
plt.show()

# %%
nx.draw_kamada_kawai(nx.lollipop_graph(3,3))
plt.title("nx.lollipop_graph(3,3)")
plt.show()
nx.draw_kamada_kawai(nx.lollipop_graph(3,4))
plt.title("nx.lollipop_graph(3,4)")
plt.show()
nx.draw_kamada_kawai(nx.lollipop_graph(4,3))
plt.title("nx.lollipop_graph(4,3)")
plt.show()

# %%
nx.draw_kamada_kawai(nx.path_graph(3))
plt.title("nx.path_graph(3)")
plt.show()
nx.draw_kamada_kawai(nx.path_graph(4))
plt.title("nx.path_graph(4)")
plt.show()
nx.draw_kamada_kawai(nx.path_graph(10))
plt.title("nx.path_graph(10)")
plt.show()

# %%
nx.draw_kamada_kawai(nx.star_graph(3))
plt.title("nx.star_graph(3)")
plt.show()
nx.draw_kamada_kawai(nx.star_graph(4))
plt.title("nx.star_graph(4)")
plt.show()
nx.draw_kamada_kawai(nx.star_graph(10))
plt.title("nx.star_graph(10)")
plt.show()

# %%
nx.draw_kamada_kawai(nx.turan_graph(3,2))
plt.title("nx.turan_graph(3,3)")
plt.show()
nx.draw_kamada_kawai(nx.turan_graph(3,3))
plt.title("nx.turan_graph(4)")
plt.show()
nx.draw_kamada_kawai(nx.turan_graph(4,3))
plt.title("nx.turan_graph(10)")
plt.show()

# %%
nx.draw_kamada_kawai(nx.wheel_graph(3))
plt.title("nx.wheel_graph(3)")
plt.show()
nx.draw_kamada_kawai(nx.wheel_graph(4))
plt.title("nx.wheel_graph(4)")
plt.show()
nx.draw_kamada_kawai(nx.wheel_graph(10))
plt.title("nx.wheel_graph(10)")
plt.show()

# %%
nx.draw_kamada_kawai(nx.margulis_gabber_galil_graph(2))
plt.title("nx.margulis_gabber_galil_graph(2)")
plt.show()
nx.draw_kamada_kawai(nx.margulis_gabber_galil_graph(3))
plt.title("nx.margulis_gabber_galil_graph(3)")
plt.show()
nx.draw_kamada_kawai(nx.margulis_gabber_galil_graph(4))
plt.title("nx.margulis_gabber_galil_graph(4)")
plt.show()

# %%
nx.draw_kamada_kawai(nx.chordal_cycle_graph(3))
plt.title("nx.chordal_cycle_graph(3)")
plt.show()
nx.draw_kamada_kawai(nx.chordal_cycle_graph(4))
plt.title("nx.chordal_cycle_graph(4)")
plt.show()
nx.draw_kamada_kawai(nx.chordal_cycle_graph(5))
plt.title("nx.chordal_cycle_graph(5)")
plt.show()

# %%
nx.draw_kamada_kawai(nx.grid_2d_graph(3,3))
plt.title("nx.grid_2d_graph(3,3)")
plt.show()
nx.draw_kamada_kawai(nx.grid_2d_graph(3,4))
plt.title("nx.grid_2d_graph(3,4)")
plt.show()
nx.draw_kamada_kawai(nx.grid_2d_graph(4,4))
plt.title("nx.grid_2d_graph(4,4)")
plt.show()

# %%
nx.draw_kamada_kawai(nx.grid_graph([3,3,2]))
plt.title("nx.grid_graph([3,3,2])")
plt.show()

# %%
nx.draw_kamada_kawai(nx.hexagonal_lattice_graph(4,2))
plt.title("nx.hexagonal_lattice_graph(4,2)")
plt.show()
nx.draw_kamada_kawai(nx.hexagonal_lattice_graph(2,3))
plt.title("nx.hexagonal_lattice_graph(2,3)")
plt.show()
nx.draw_kamada_kawai(nx.hexagonal_lattice_graph(3,3))
plt.title("nx.hexagonal_lattice_graph(3,3)")
plt.show()

# %%
nx.draw_kamada_kawai(nx.hypercube_graph(2))
plt.title("nx.hypercube_graph(2)")
plt.show()
nx.draw_kamada_kawai(nx.hypercube_graph(3))
plt.title("nx.hypercube_graph(3)")
plt.show()
nx.draw_kamada_kawai(nx.hypercube_graph(4))
plt.title("nx.hypercube_graph(4)")
plt.show()

# %%
nx.draw_kamada_kawai(nx.triangular_lattice_graph(2,2))
plt.title("nx.triangular_lattice_graph(2,2)")
plt.show()
nx.draw_kamada_kawai(nx.triangular_lattice_graph(2,3))
plt.title("nx.triangular_lattice_graph(2,3)")
plt.show()
nx.draw_kamada_kawai(nx.triangular_lattice_graph(3,3))
plt.title("nx.triangular_lattice_graph(3,3)")
plt.show()

# %%
nx.draw_kamada_kawai(nx.bull_graph())
plt.title("nx.bull_graph()")
plt.show()

# %%
nx.draw_kamada_kawai(nx.chvatal_graph())
plt.title("nx.chvatal_graph()")
plt.show()

# %%
nx.draw_kamada_kawai(nx.cubical_graph())
plt.title("nx.cubical_graph()")
plt.show()

# %%
nx.draw_kamada_kawai(nx.desargues_graph())
plt.title("nx.desargues_graph()")
plt.show()

# %%
nx.draw_kamada_kawai(nx.diamond_graph())
plt.title("nx.diamond_graph()")
plt.show()

# %%
nx.draw_kamada_kawai(nx.dodecahedral_graph())
plt.title("nx.dodecahedral_graph()")
plt.show()

# %%
nx.draw_kamada_kawai(nx.frucht_graph())
plt.title("nx.frucht_graph()")
plt.show()

# %%
nx.draw_kamada_kawai(nx.heawood_graph())
plt.title("nx.heawood_graph()")
plt.show()

# %%
nx.draw_kamada_kawai(nx.house_graph())
plt.title("nx.house_graph()")
plt.show()

# %%
nx.draw_kamada_kawai(nx.house_x_graph())
plt.title("nx.house_x_graph()")
plt.show()

# %%
nx.draw_kamada_kawai(nx.icosahedral_graph())
plt.title("nx.icosahedral_graph()")
plt.show()

# %%
nx.draw_kamada_kawai(nx.krackhardt_kite_graph())
plt.title("nx.krackhardt_kite_graph()")
plt.show()

# %%
nx.draw_kamada_kawai(nx.moebius_kantor_graph())
plt.title("nx.moebius_kantor_graph()")
plt.show()

# %%
nx.draw_kamada_kawai(nx.octahedral_graph())
plt.title("nx.octahedral_graph()")
plt.show()

# %%
nx.draw_kamada_kawai(nx.pappus_graph())
plt.title("nx.pappus_graph()")
plt.show()

# %%
nx.draw_kamada_kawai(nx.petersen_graph())
plt.title("nx.petersen_graph()")
plt.show()

# %%
nx.draw_kamada_kawai(nx.sedgewick_maze_graph())
plt.title("nx.sedgewick_maze_graph()")
plt.show()

# %%
nx.draw_kamada_kawai(nx.tetrahedral_graph())
plt.title("nx.tetrahedral_graph()")
plt.show()

# %%
nx.draw_kamada_kawai(nx.truncated_tetrahedron_graph())
plt.title("nx.truncated_tetrahedron_graph()")
plt.show()

# %%
nx.draw_kamada_kawai(nx.tutte_graph())
plt.title("nx.tutte_graph()")
plt.show()

# %%
aaa
